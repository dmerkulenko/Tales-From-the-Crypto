# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


# %matplotlib inline

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
print(api_key)
# Out:
# 22340e782dda4cb9a30800ab80c06360

# %%
# Create a newsapi client
from newsapi import NewsApiClient

newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles

bitcoin_news = newsapi.get_everything(
    q="bitcoin",
    language = "en",
    page_size = 100,
    sort_by = "relevancy")

# %%
# Fetch the Ethereum news articles

ethereum_news = newsapi.get_everything(
    q="ethereum",
    language = "en",
    page_size = 100,
    sort_by = "relevancy")

# %%
# Create the Bitcoin sentiment scores DataFrame

sentiments = []

for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment ["pos"]
        neu = sentiment ["neu"]
        neg = sentiment["neg"]
        
        sentiments.append({
            "text" : text,
            "Compound" : compound,
            "Positive" : pos,
            "Negative" : neg,
            "Neutral" : neu
        })
    except AttributeError:
        pass
    
#Create DataFrame

bitcoin_df = pd.DataFrame(sentiments)

#Reordering the column order

#cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
#bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#                                                 text  Compound  Positive  \
# 0  Its set to open later this year\r\nIf you buy ...   -0.4404     0.000
# 1  Wikipedia editors have voted in favor of dropp...    0.4019     0.088
# 2  You might have heard of crypto Twitter, the co...   -0.2732     0.000
# 3  The wallet will have USB-C and a fingerprint r...   -0.4404     0.000
# 4  German authorities have seized $25.2 million U...    0.0000     0.000
#
#    Negative  Neutral
# 0     0.081    0.919
# 1     0.000    0.912
# 2     0.057    0.943
# 3     0.088    0.912
# 4     0.000    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
sentiments =[]

for articles in ethereum_news["articles"]:
    try:
        text = articles["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment ["neu"]
        neg = sentiment ["neg"]
        
        sentiments.append({
            "text" : text,
            "Compound" : compound,
            "Positive" : pos,
            "Negative" : neg,
            "Neutral" : neu
        })
    except AttributeError:
        pass
#Create DataFrame

ethereum_df = pd.DataFrame(sentiments)

#Reordering the column order

#cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
#ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#                                                 text  Compound  Positive  \
# 0  Digital thieves just pulled off another major ...   -0.5106     0.000
# 1  The US Department of Treasury says Lazarus is ...   -0.7845     0.088
# 2  18 with 15 posters participating, including st...    0.1027     0.084
# 3  This week, the cryptocurrency network Ronin di...   -0.4215     0.051
# 4  Opera launched its dedicated "Crypto Browser" ...    0.7351     0.188
#
#    Negative  Neutral
# 0     0.102    0.898
# 1     0.231    0.681
# 2     0.071    0.844
# 3     0.098    0.851
# 4     0.000    0.812

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.183480    0.069880    0.027730    0.902400
# std      0.349712    0.064622    0.041492    0.075325
# min     -0.709600    0.000000    0.000000    0.693000
# 25%      0.000000    0.000000    0.000000    0.852000
# 50%      0.152950    0.072500    0.000000    0.912000
# 75%      0.462950    0.113250    0.065500    0.950500
# max      0.865500    0.263000    0.162000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.209433    0.091110    0.037250    0.871620
# std      0.405902    0.081044    0.051962    0.090757
# min     -0.784500    0.000000    0.000000    0.594000
# 25%      0.000000    0.000000    0.000000    0.805500
# 50%      0.232250    0.078500    0.000000    0.885000
# 75%      0.528675    0.138000    0.068750    0.934000
# max      0.932700    0.349000    0.233000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum had a little higher mean positive score
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin had the highest compound score
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin had the highest positive score

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dariamerkulenko/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = stopwords.words('english')

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
   
    # Create a tokenized list of the words
    
    words = word_tokenize(text)
    
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    
    # Lemmatize words into root words
    
    tokens = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the stop words
    
    words = list(filter(lambda t: t.lower() not in sw, words))
    
    return tokens

# %%
# Create a new tokens column for Bitcoin

bitcoin_df["Tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#                                                 text  Compound  Positive  \
# 0  Its set to open later this year\r\nIf you buy ...   -0.4404     0.000
# 1  Wikipedia editors have voted in favor of dropp...    0.4019     0.088
# 2  You might have heard of crypto Twitter, the co...   -0.2732     0.000
# 3  The wallet will have USB-C and a fingerprint r...   -0.4404     0.000
# 4  German authorities have seized $25.2 million U...    0.0000     0.000
#
#    Negative  Neutral                                             Tokens
# 0     0.081    0.919  [Its, set, to, open, later, this, year, If, yo...
# 1     0.000    0.912  [Wikipedia, editor, have, voted, in, favor, of...
# 2     0.057    0.943  [You, might, have, heard, of, crypto, Twitter,...
# 3     0.088    0.912  [The, wallet, will, have, USB-C, and, a, finge...
# 4     0.000    1.000  [German, authority, have, seized, 25.2, millio...

# %%
# Create a new tokens column for Ethereum
ethereum_df["Tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#                                                 text  Compound  Positive  \
# 0  Digital thieves just pulled off another major ...   -0.5106     0.000
# 1  The US Department of Treasury says Lazarus is ...   -0.7845     0.088
# 2  18 with 15 posters participating, including st...    0.1027     0.084
# 3  This week, the cryptocurrency network Ronin di...   -0.4215     0.051
# 4  Opera launched its dedicated "Crypto Browser" ...    0.7351     0.188
#
#    Negative  Neutral                                             Tokens
# 0     0.102    0.898  [Digital, thief, just, pulled, off, another, m...
# 1     0.231    0.681  [The, US, Department, of, Treasury, say, Lazar...
# 2     0.071    0.844  [18, with, 15, poster, participating, includin...
# 3     0.098    0.851  [This, week, the, cryptocurrency, network, Ron...
# 4     0.000    0.812  [Opera, launched, it, dedicated, ``, Crypto, B...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N=2

btc_grams = ngrams(tokenizer(bitcoin_df.text.str.cat()),N)

Counter(btc_grams).most_common(20)
# Out:
# [(('in', 'the'), 19),
#  (('of', 'the'), 16),
#  (('the', 'world'), 15),
#  (('char', 'The'), 8),
#  (('the', 'Bitcoin'), 7),
#  (('to', 'the'), 7),
#  (('char', 'April'), 7),
#  (('world', "'s"), 7),
#  (('char', 'LONDON'), 7),
#  (('NFTs', 'and'), 6),
#  (('is', 'the'), 6),
#  (('this', 'year'), 5),
#  (('for', 'the'), 5),
#  (('Bitcoin', 'is'), 5),
#  (('bitcoin', 'a'), 5),
#  (('on', 'Thursday'), 5),
#  (('at', 'the'), 5),
#  (('one', 'of'), 5),
#  (('this', 'week'), 5),
#  (('the', 'latest'), 5)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
eth_grams = ngrams(tokenizer(ethereum_df.text.str.cat()), N)
Counter(eth_grams).most_common(20)
# Out:
# [(('of', 'the'), 18),
#  (('the', 'world'), 12),
#  (('char', 'The'), 10),
#  (('Ethereum', 'ETH'), 10),
#  (('Axie', 'Infinity'), 9),
#  (('one', 'of'), 9),
#  (('in', 'the'), 9),
#  (('to', 'the'), 8),
#  (('char', 'April'), 7),
#  (('on', 'the'), 7),
#  (('North', 'Korean'), 6),
#  (('this', 'week'), 6),
#  (('is', 'a'), 6),
#  (('world', "'s"), 6),
#  (('from', 'the'), 5),
#  (('the', 'most'), 5),
#  (('year', 'and'), 5),
#  (('with', 'the'), 5),
#  (('ha', 'been'), 5),
#  (('million', 'in'), 4)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
world_tokens = tokenizer(bitcoin_df.text.str.cat())
token_count(world_tokens, 10)
# Out:
# [('the', 152),
#  ('a', 101),
#  ('char', 95),
#  ('to', 88),
#  ('of', 78),
#  ('and', 60),
#  ('in', 59),
#  ('on', 40),
#  ("'s", 36),
#  ('is', 35)]

# %%
# Use token_count to get the top 10 words for Ethereum
world_tokens = tokenizer(ethereum_df.text.str.cat())
token_count(world_tokens, 10)
# Out:
# [('the', 134),
#  ('char', 100),
#  ('a', 80),
#  ('to', 75),
#  ('and', 70),
#  ('of', 68),
#  ('in', 59),
#  ('is', 41),
#  ('The', 36),
#  ('on', 35)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()

# %%
# Generate the Bitcoin word cloud
wordcloud(bitcoin_df.text.str.cat(), title="Bitcoin Word Cloud")

# %%
# Generate the Ethereum word cloud
wordcloud(ethereum_df.text.str.cat(), title="Ethereum Word Cloud")

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_btc_text = bitcoin_df.text.str.cat()
all_btc_text
# Out:
# 'Its set to open later this year\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nIllustration by Alex Castro / The Verge\r\nBlock and Blockstream, a … [+1336 chars]Wikipedia editors have voted in favor of dropping cryptocurrency from the Wikimedia Foundation\'s donation options. As Ars Technica reports, an editor for the online encyclopedia called GorillaWarfare… [+1577 chars]You might have heard of crypto Twitter, the corner of the social network where accounts have Bored Apes as profile pictures, posts are rife with talk of tokens, blockchains, and buying the Bitcoin di… [+3133 chars]The wallet will have USB-C and a fingerprint reader. | Image: @JesseDorogusker on Twitter\r\n\n \n\n We may have just seen the Bitcoin hardware wallet that Jack Dorsey’s Block (the company formerly known … [+1777 chars]German authorities have seized $25.2 million USD in Bitcoin\r\nGerman authorities shut down the server infrastructure for the Russian darknet marketplace Hydra, seizing 23 million (~$25.2 million USD) … [+2344 chars]Bitcoin hit a milestone Friday "that gets the world ever closer to the moment when the final new bitcoin will enter the world," reports Axios. "The supply of coins broke 19 million...""Bitcoin is har… [+641 chars]April 12 (Reuters) - A crypto platform\'s pledge to amass $10 billion worth of bitcoin to back its own "stablecoin" is firing up the market. It\'s part of a wider movement to crown bitcoin as the reser… [+5660 chars]MIAMI BEACH, April 7 (Reuters) - Bitcoin entrepreneur Samson Mow on Thursday said he has created a new company called Jan3 focused on promoting bitcoin adoption, adding that the firm has signed a mem… [+1360 chars]The news:\xa0Block\xa0CEO Jack Dorsey announced three new \r\nCash App services at the Bitcoin 2022 conference on Thursday, per CoinDesk.\r\nInsider Intelligence\r\n"Paid in Bitcoin" lets Cash App users auto-inv… [+2872 chars]18 with 15 posters participating, including story author\r\nMore than 200 long-time Wikipedia editors have requested that the Wikimedia Foundation stop accepting cryptocurrency donations.\xa0The foundatio… [+4016 chars]This week, the cryptocurrency network Ronin disclosed a breach in which attackers made off with $540 million worth of Ethereum and USDC stablecoin. The incident, which is one of the biggest heists in… [+3084 chars]March 27 (Reuters) - Bitcoin surged 4.41% to $46,499.29 at 22:07 GMT on Sunday, adding $1,963.64 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 41.1% from t… [+353 chars]April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 16% from the year\'s low … [+339 chars]Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars]Authorities aren\'t done busting dark web crime operations this week. German federal police (the Bundeskriminalamt) working with US law enforcement have seized Hydra Market, billed as the world\'s larg… [+1524 chars]Block disclosed today that a security breach involving a former employee impacts 8.2 million Cash App users. In an SEC filing, the company reported that an ex-employee on December 10th downloaded a n… [+1646 chars]Opera launched its dedicated "Crypto Browser" into beta back in January, promising to make Web3 as accessible as any Web2 website. The company released the browser for Windows, Mac and Android users … [+1563 chars]The Central African Republic has adopted bitcoin as legal tender, making it the second nation in the world -- after El Salvador -- to do so. On Wednesday, President Faustin Archange Touadera\'s office… [+1078 chars]If you want to pay online, you need to register an account and provide credit card information. If you don\ ...

# %%
# Run the NER processor on all of the text
btc_ner = nlp(all_btc_text)

# Add a title to the document
btc_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(btc_ner, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Its set to open
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     later this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>If you buy something from a
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  link,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vox Media
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Block and Blockstream, a … [+1336 chars]Wikipedia editors have voted in favor of dropping cryptocurrency from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Wikimedia Foundation's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  donation options. As
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ars Technica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reports, an editor for the online encyclopedia called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GorillaWarfare
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1577 chars]You might have heard of crypto
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the corner of the social network where accounts have
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bored Apes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as profile pictures, posts are rife with talk of tokens, blockchains, and buying the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  di… [+3133 chars]The wallet will have
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USB-C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and a fingerprint reader. | Image: @JesseDorogusker on
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br></br> </br></br> We may have just seen the Bitcoin hardware wallet that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jack Dorsey’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Block (the company formerly known … [+1777 chars]German authorities have seized
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $25.2 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  USD in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities shut down the server infrastructure for the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  darknet marketplace
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hydra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , seizing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (~$25.2 million USD) … [+2344 chars]Bitcoin hit a milestone
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  &quot;that gets the world ever closer to the moment when the final new bitcoin will enter the world,&quot; reports
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Axios
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . &quot;The supply of coins broke
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;"

# %%
# List all Entities
for ent in btc_ner.ents:
    print(ent.text, ent.label_)
# Out:
# later this year DATE
# Verge LAW
# Vox Media ORG
# Alex Castro PERSON
# Verge ORG
# the Wikimedia Foundation's ORG
# Ars Technica PERSON
# GorillaWarfare ORG
# Twitter PRODUCT
# Bored Apes PERSON
# Bitcoin PERSON
# USB-C ORG
# Twitter PRODUCT
# Jack Dorsey’s PERSON
# $25.2 million MONEY
# Bitcoin GPE
# German NORP
# Russian NORP
# Hydra GPE
# 23 million CARDINAL
# Friday DATE
# Axios PERSON
# 19 million CARDINAL
# Reuters ORG
# $10 billion MONEY
# BEACH GPE
# April 7 DATE
# Reuters ORG
# Samson Mow PERSON
# Thursday DATE
# Jan3 ORG
# Jack Dorsey PERSON
# three CARDINAL
# Cash App PERSON
# Bitcoin 2022 DATE
# Thursday DATE
# CoinDesk ORG
# Intelligence ORG
# Cash App PERSON
# 15 CARDINAL
# More than 200 CARDINAL
# Wikipedia ORG
# the Wikimedia Foundation ORG
# Ronin ORG
# $540 million MONEY
# Ethereum GPE
# USDC ORG
# 27 CARDINAL
# Reuters ORG
# 4.41% PERCENT
# 46,499.29 MONEY
# Sunday DATE
# 1,963.64 MONEY
# Bitcoin PERSON
# 41.1% PERCENT
# Reuters ORG
# 5.1% PERCENT
# 38,391.36 MONEY
# Tuesday DATE
# 2,229.82 MONEY
# Bitcoin PERSON
# 16% PERCENT
# year DATE
# +339 ORG
# AMC ORG
# April 15 DATE
# AMC ORG
# Adam Aron PERSON
# moviego GPE
# this week DATE
# German NORP
# US GPE
# Hydra Market PERSON
# +1524 ORG
# today DATE
# 8.2 million CARDINAL
# Cash App PERSON
# SEC ORG
# December 10th DATE
# Crypto Browser PERSON
# January DATE
# Windows, Mac ORG
# Android ORG
# second ORDINAL
# El Salvador GPE
# Wednesday DATE
# Faustin Archange PERSON
# 29 CARDINAL
# Reuters ORG
# first quarter DATE
# $2 trillion MONEY
# March 31 DATE
# Reuters ORG
# European Union ORG
# Thursday DATE
# April 7 DATE
# Reuters ORG
# Honduras GPE
# Caribbean LOC
# April 27 DATE
# Reuters ORG
# Wednesday DATE
# first ORDINAL
# Africa LOC
# second ORDINAL
# March 29 DATE
# Reuters ORG
# Tuesday DATE
# this year DATE
# a day earlier DATE
# 27% PERCENT
# Russia GPE
# Transform ORG
# July 19 DATE
# July 20 - 28 DATE
# today DATE
# PayPal ORG
# Donald Trump PERSON
# Warren Buffett PERSON
# Jamie Dimon PERSON
# Joel Greenblatt PERSON
# Sweden GPE
# US GPE
# $20 million MONEY
# Miami GPE
# Thursday DATE
# one CARDINAL
# first ORDINAL
# Bitcoin: Mexico WORK_OF_ART
# Senate ORG
# the Mexican Republic GPE
# chars]April 1 DATE
# Reuters ORG
# Friday DATE
# the United States GPE
# March 31 DATE
# Reuters ORG
# European Union ORG
# Thursday DATE
# Tesla ORG
# Honduras GPE
# week DATE
# Francesca Lynagh PERSON
# chars]More than 200 CARDINAL
# Wikipedia ORG
# the Wikimedia Foundation ORG
# about $130,000 MONEY
# chars]April 26 DATE
# Reuters ORG
# No.2 DATE
# Thailand GPE
# today DATE
# Bitcoin PERSON
# Verge ORG
# chars]April 5 DATE
# Reuters ORG
# Last week DATE
# U.S. GPE
# Joe Mullally PERSON
# International Monetary Fund ORG
# El Salvador GPE
# one CARDINAL
# the Los Angeles Times ORG
# one CARDINAL
# decades DATE
# Russian NORP
# the Wagner Group ORG
# Glassnode ORG
# Monday DATE
# almost three quarters CARDINAL
# Achilles PERSON
# This week DATE
# Bitcoin 2022 DATE
# Miami GPE
# this week DATE
# 2021 DATE
# Ethereum ORG
# Aparna Chennapragada PERSON
# Bitcoin 2022 DATE
# Miami GPE
# ETH ORG
# Uber ORG
# Dara Khosrowshahi PERSON
# chars]HONG KONG GPE
# March 28 DATE
# Reuters ORG
# Japanese NORP
# Monday DATE
# morning TIME
# the Bank of Japan ORG
# ATM ORG
# Hong Kong GPE
# 2017 DATE
# Kin Cheung PERSON
# AP ORG
# NEW YORK GPE
# January 2021 DATE
# Miami GPE
# Francis Suarez PERSON
# Twitter PRODUCT
# The City of Miami GPE
# # CARDINAL
# this week DATE
# Getty Images ORG
# Nonfungible Tidbits PERSON
# weekly DATE
# this week DATE
# Taxes 2022 ORG
# CNET ORG
# March 30 DATE
# Reuters ORG
# almost $615 million MONEY
# Axie Infinity GPE
# chars]NEW YORK GPE
# April 8 DATE
# Reuters ORG
# U.S. GPE
# the latest week DATE
# Reuters ORG
# U.S. Commodity Futures Trading Commission ORG
# YouTube ORG
# UK GPE
# Monday DATE
# the Innovate Finance Global Sum ORG
# Cayman ORG
# Michele Doying PERSON
# Verge ORG
# 2A CARDINAL
# US GPE
# The Electronic Currency ORG
# Secure Hardware PERSON
# $3 trillion MONEY
# around $2 trillion MONEY
# today DATE
# April 25 DATE
# Reuters ORG
# Canadian NORP
# Monday DATE
# Conservative NORP
# Fidelity ORG
# Tuesda ORG
# Tuesday DATE
# Nasdaq ORG
# 2.3% PERCENT
# Federal Reserve ORG
# Fed ORG
# Lael Brainard PERSON
# Friday DATE
# nearly 1,000 CARDINAL
# Fed ORG
# Jerome Powell PERSON
# 2009 DATE
# around US$2 trillion MONEY
# 1 MONEY
# 2011 DATE
# Joe TidyCyber PERSON
# German NORP
# months DATE
# Sebastian Zwiebel PERSON
# this year DATE
# Metaverse ORG
# this year DATE
# Metaverse ORG
# April 27 DATE
# Reuters ORG
# Cuban NORP
# Tuesday DATE
# last year DATE
# 31 DATE
# Reuters ORG
# Bank of New York Mellon Corp ORG
# USD Coin ORG
# Dan WhitworthMoney PERSON
# BBC Radio ORG
# 4 CARDINAL
# Getty Images ORG
# one CARDINAL
# Radio 4 Money Box ORG
# the last week DATE
# Greek NORP
# 2021 DATE
# the year DATE
# TSLA ORG
# TWTR ORG
# AAPL ORG
# $20 billion MONEY
# this year DATE
# Wednesday DATE
# hundreds CARDINAL
# more than $25 million MONEY
# this week DATE
# Eoneren/iStock/Getty Images ORG
# This week DATE
# UK GPE
# Monday DATE
# several months ago DATE
# 8.2 million CARDINAL
# Cash App PERSON
# CityCoins ORG
# Patrick Stanley PERSON
# first ORDINAL
# 2009 DATE
# the decade DATE
# Bitcoin PERSON
# chars]April 19 DATE
# Reuters ORG
# Coins PERSON
# April 4 DATE
# Reuters ORG
# Britain GPE
# Monday DATE
# Reuters ORG
# Stripe Inc PERSON
# chars]The Impervious Browser WORK_OF_ART
# April 7th DATE
# the Bitcoin 2022 Conference EVENT
# Miami GPE
# March 13, 2015 DATE
# more than two years DATE
# April 15 DATE
# Reuters ORG
# two-decade DATE
# two-year DATE
# Friday DATE
# Federal Reserve ORG
# seventh ORDINAL
# CRYPTOLAND ORG
# Motherboard’s ORG
# Tuesday DATE
# Fidelity Investments ORG
# 401(k)s DATE
# Greenberg PERSON
# a few years DATE
# eToro ORG
# CopyPortfolios ORG
# CopyTrader ORG
# Reuters ORG
# FILE ORG
# Card PERSON
# July 15, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo PERSON
# LONDON GPE
# Reuters ORG
# April 8 DATE
# Reuters ORG
# The European Union ORG
# Friday DATE
# fifth ORDINAL
# Russia GPE
# March 29 DATE
# Reuters ORG
# French NORP
# Monaco PERSON
# Tuesday DATE
# Capital Block ORG
# April 13 DATE
# Reuters ORG
# Nexo PERSON
# Mastercard ORG
# Wednesday DATE
# first ORDINAL

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the bitcoin text together
all_eth_text = ethereum_df.text.str.cat()
all_eth_text
# Out:
# 'Digital thieves just pulled off another major crypto heist. Motherboard has learned hackers stole 173,600 Ethereum (about $591.2 million) from the Ronin blockchain that powers Axie Infinity, a popula… [+1462 chars]The US Department of Treasury says Lazarus is behind the attack\r\nThe US Treasury Department blames North Korean hacking group Lazarus for stealing $625 million in cryptocurrency from the Ronin networ… [+1853 chars]18 with 15 posters participating, including story author\r\nMore than 200 long-time Wikipedia editors have requested that the Wikimedia Foundation stop accepting cryptocurrency donations.\xa0The foundatio… [+4016 chars]This week, the cryptocurrency network Ronin disclosed a breach in which attackers made off with $540 million worth of Ethereum and USDC stablecoin. The incident, which is one of the biggest heists in… [+3084 chars]Opera launched its dedicated "Crypto Browser" into beta back in January, promising to make Web3 as accessible as any Web2 website. The company released the browser for Windows, Mac and Android users … [+1563 chars]April 5 (Reuters) - Ethereum blockchain scaling platform Boba Network raised $45 million in its series A round, with participation from investors including Will Smith-led Dreamers VC, Paris Hilton an… [+1335 chars]The news:\xa0A former developer of the cryptocurrency Ethereum was sentenced to more than five years in prison and fined $100,000 for\xa0helping North Korea use cryptos to evade US sanctions,\xa0per NBC News.… [+2438 chars]April 26 (Reuters) - Ether has promised to do better. It has promised to go to the next level, edging out crypto rivals and even outshining the godfather, bitcoin. But the clock\'s ticking.\r\nThe No.2 … [+4092 chars]Regulatory solutions should be codified regionally and internationally through compatible language and legal definitions. Policy solutions like online harms and safety bills could be used to expand r… [+5103 chars]Ethereum is preparing for an upgrade thats been described as the single most important event in crypto history.\r\nThe transition would overhaul the infrastructure of the worlds second-largest blockcha… [+2824 chars]The Brave Browser promotes itself as a Google Chrome alternative focused on privacy, but its default settings arent the most privacy friendly. If you need to use a Chrome-based browser, Brave is defi… [+3493 chars]We are excited to bring Transform 2022 back in-person July 19 and virtually July 20 - August 3. Join AI and data leaders for insightful talks and exciting networking opportunities. Learn More\r\nThe $6… [+2977 chars]Dogecoiners unite! Movie theater chain AMC has welcomed some more cryptocurrencies as payment options for online and mobile purchases. In a tweet on April 15, AMC CEO Adam Aron announced that moviego… [+1603 chars]Early this week, the Ukrainian Computer Emergency Response Team and Slovakian cybersecurity firm ESET warned that Russia\'s notorious GRU Sandworm hackers had targeted high-voltage electrical substati… [+3937 chars]One of the leading Ethereum software developers said the blockchain network’s much-anticipated technical upgrade known as the Merge will likely be completed a few months after June.\r\nThe comment help… [+1965 chars]I first wrote about the problem of bots front-running transactions a year and a half ago in The Order Flow, citing Dan Robinson and Georgios Konstantopoulos\'\r\nEthereum is a Dark Forest from August 20… [+23406 chars]April 26 (Reuters) - Bitcoin dropped 5.1% to $38,391.36 on Tuesday, down $2,229.82 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 16% from the year\'s low … [+339 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $25 billion ov… [+2980 chars]March 27 (Reuters) - Bitcoin surged 4.41% to $46,499.29 at 22:07 GMT on Sunday, adding $1,963.64 to its previ ...

# %%
# Run the NER processor on all of the text
eth_ner = nlp(all_eth_text)

# Add a title to the document
eth_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_ner, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Digital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  thieves just pulled off another major crypto heist.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Motherboard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has learned hackers stole
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     173,600
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $591.2 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) from the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain that powers
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Axie Infinity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , a popula… [+1462 chars]The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lazarus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The US Treasury Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blames
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Korean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  hacking group
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lazarus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for stealing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $625 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency from the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  networ… [+1853 chars]18 with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than 200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  long-time
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  editors have requested that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Wikimedia Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stop accepting cryptocurrency donations. The foundatio… [+4016 chars]This week, the cryptocurrency network
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ronin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  disclosed a breach in which attackers made off with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $540 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USDC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stablecoin. The incident, which is one of the biggest heists in… [+3084 chars]Opera launched its dedicated &quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto Browser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em;

# %%
# List all Entities
for ent in eth_ner.ents:
    print(ent.text, ent.label_)
# Out:
# Digital ORG
# Motherboard PERSON
# 173,600 CARDINAL
# Ethereum ORG
# about $591.2 million MONEY
# Ronin ORG
# Axie Infinity GPE
# US Department ORG
# Treasury ORG
# Lazarus PERSON
# The US Treasury Department ORG
# North Korean NORP
# Lazarus ORG
# $625 million MONEY
# Ronin PERSON
# 15 CARDINAL
# More than 200 CARDINAL
# Wikipedia ORG
# the Wikimedia Foundation ORG
# Ronin ORG
# $540 million MONEY
# Ethereum GPE
# USDC ORG
# Crypto Browser PERSON
# January DATE
# Windows, Mac ORG
# Android ORG
# Reuters ORG
# Boba Network PERSON
# $45 million MONEY
# Will Smith-led PERSON
# Dreamers VC ORG
# Paris Hilton PERSON
# Ethereum ORG
# more than five years DATE
# 100,000 MONEY
# North Korea GPE
# US GPE
# NBC News ORG
# Reuters ORG
# No.2 DATE
# second ORDINAL
# Chrome ORG
# Brave ORG
# Transform ORG
# July 19 DATE
# July 20 - August 3 DATE
# 6 MONEY
# AMC ORG
# April 15 DATE
# AMC ORG
# Adam Aron PERSON
# moviego GPE
# this week DATE
# the Ukrainian Computer Emergency Response Team ORG
# Slovakian NORP
# Russia GPE
# GRU Sandworm PERSON
# Ethereum ORG
# Merge ORG
# a few months after June DATE
# a year and a half ago DATE
# The Order Flow WORK_OF_ART
# Dan Robinson PERSON
# Georgios Konstantopoulos' ORG
# Ethereum ORG
# Dark Forest ORG
# August 20 DATE
# 26 CARDINAL
# Reuters ORG
# 5.1% PERCENT
# 38,391.36 MONEY
# Tuesday DATE
# 2,229.82 MONEY
# Bitcoin PERSON
# 16% PERCENT
# year DATE
# +339 ORG
# the past few years DATE
# NFT ORG
# $25 billion MONEY
# 27 CARDINAL
# Reuters ORG
# 4.41% PERCENT
# 46,499.29 MONEY
# Sunday DATE
# 1,963.64 MONEY
# Bitcoin PERSON
# 41.1% PERCENT
# Reuters ORG
# five years and three months DATE
# Tuesday DATE
# North Korea GPE
# U.S. GPE
# Aparna Chennapragada PERSON
# Bitcoin 2022 DATE
# Miami GPE
# ETH ORG
# Ronin GPE
# February 2021 DATE
# Ethereum ORG
# Axie Infinity GPE
# Ethereum ORG
# Ronin ORG
# Transform ORG
# July 19 DATE
# July 20 - 28 DATE
# today DATE
# coali NORP
# Finance Insider PERSON
# American Express ORG
# this morning TIME
# Ethereum ORG
# +2093 ORG
# Reuters ORG
# Stripe Inc PERSON
# FBI ORG
# Ronin PERSON
# North Korean NORP
# chars]The U.S. Department of Justice ORG
# two CARDINAL
# European NORP
# North Korean NORP
# 2019 DATE
# One CARDINAL
# 30 CARDINAL
# Axie Infinity GPE
# Ronin ORG
# eToro ORG
# CopyPortfolios ORG
# CopyTrader ORG
# +1.25% PERCENT
# ETHUSD ORG
# +4.68% PERCENT
# recent years DATE
# Bitcoin 2022 DATE
# Miami GPE
# this week DATE
# 2021 DATE
# Ethereum ORG
# DeFi GPE
# more than $600 million MONEY
# USDC ORG
# Ronin ORG
# Axie Infinity GPE
# last month DATE
# more than $500 MONEY
# Ronin ORG
# second ORDINAL
# TikTok ORG
# half CARDINAL
# Instagram ORG
# YouTube ORG
# NurPhoto ORG
# Tim Be PERSON
# Wikipedia ORG
# the Wikimedia Foundation ORG
# about $130,000 MONEY
# one CARDINAL
# U.S. Treasury Department ORG
# Ethereum ORG
# Axie Infinity GPE
# North Korean NORP
# Thursday DATE
# Leonardo PERSON
# Joe Kennedy PERSON
# London GPE
# Hohndel ORG
# Slashdot GPE
# the last five years DATE
# VMware ORG
# 2022 DATE
# Ethereum ORG
# 2021 DATE
# 2,000 acres QUANTITY
# about US$4 million MONEY
# chars]NEW YORK GPE
# March 31 DATE
# Reuters ORG
# Thursday DATE
# Binance PERSON
# U.S. GPE
# U.S. Treasury Department ORG
# North Korean NORP
# Lazarus ORG
# more than $600 million MONEY
# this week DATE
# Getty Images ORG
# Nonfungible Tidbits PERSON
# weekly DATE
# this week DATE
# Live Forever' WORK_OF_ART
# over years DATE
# Somnium Space ORG
# Points ORG
# Ronin PERSON
# 173,600 CARDINAL
# 25.5M USDC PERCENT
# Ronin PERSON
# Katana Dex PERSON
# almost $700 million MONEY
# 2022 DATE
# Binance PERSON
# well over half CARDINAL
# Tuesday DATE
# 2022 DATE
# OpenSea ORG
# one CARDINAL
# chars]April 25 DATE
# Reuters ORG
# Distributed Ledger PERSON
# weekly DATE
# Thursday DATE
# Frances Yue PERSON
# MarketWatch ORG
# Ill GPE
# NFT ORG
# one CARDINAL
# this week DATE
# North Korean NORP
# $625 million MONEY
# Axie Infinity GPE
# DeFi GPE
# Mars LOC
# second ORDINAL
# today DATE
# CISA GPE
# Sam Bankman-Fried PERSON
# 28 CARDINAL
# Forbes ORG
# $26.5 billion dollars MONEY
# FTX Trading Limited ORG
# one CARDINAL
# Nvidia Corp. ORG
# Monday DATE
# Bairds Tristan Gerra ORG
# NVDA ORG
# -4.66% PERCENT
# Stripe ORG
# Getty ORG
# Stripe PERSON
# Friday DATE
# Twitter PRODUCT
# NFT ORG
# Ethereum ORG
# Sarah Tew PERSON
# CNET ORG
# Coinbase ORG
# NFT ORG
# Wednesday DATE
# Last fall DATE
# chars]Last week DATE
# around $624 million MONEY
# Axie Infinity GPE
# Dive ORG
# daily DATE
# Dive ORG
# daily DATE
# Bored Ape Yacht Club ORG
# New York GPE
# last December DATE
# Comedian Aziz Ansari PERSON
# Beck PERSON
# this weeks DATE
# Bloomberg PERSON
# Bloomberg Intelligence PERSON
# Coinbase Is PERSON
# Exchang GPE
# 2022 DATE
# April 26-28th DATE
# Masnick PERSON
# last week DATE
# First ORDINAL
# chars]April 5 DATE
# Reuters ORG
# Last week DATE
# U.S. GPE
# April 15 DATE
# Reuters ORG
# Dhidhaj Sumedhsvast ORG
# two years ago DATE
# Motherboard PERSON
# This week DATE
# +1282 ORDINAL
# the last year DATE
# March 22 DATE
# Transform ORG
# July 19 DATE
# July 20 - 28 DATE
# today DATE
# thousands CARDINAL
# Ethereum(ETH -3.30% PERSON
# second ORDINAL
# Twitter PRODUCT
# ETH ORG
# -0.00% PERCENT
# second ORDINAL
# DeFi GPE
# ETH ORG
# 0.21% PERCENT
# 1.41% PERCENT
# March 2020 DATE
# 500 CARDINAL
# the last few years DATE
# one CARDINAL
# Ethereum ORG
# Ethereum ORG
# Ethereum ORG
# 1.09% PERCENT
# NFT ORG
# The Crypto Show WORK_OF_ART
# Motley Fool Live WORK_OF_ART
# March 23 DATE
# 4.03% PERCENT
# ETH ORG
# 4.58% PERCENT
# ETH ORG
# 0.28% PERCENT
# 1.88% PERCENT
# 2.59% PERCENT
# second ORDINAL
# Ethereum ORG
# NFT ORG
# Solana PERSON
# -6.85% PERCENT
# this April DATE
# Ethereum ORG
# ETH -5.27% ORG
# +3035 PERSON
# 500 MONEY
# Ethereum ORG
# ETH ORG
# -3.94% PERCENT
# NFT ORG
# Decrypt PERSON
# Solana PERSON
# Okay Bears ORG
# yesterday DATE
# +867 PRODUCT
# Levine: Can ORG
# One CARDINAL
# recent years DATE
# Innova PERSON
# U.S. GPE
# Ethereum ORG
# Virgil Griffith PERSON
# five years and three months DATE
# 100,000 MONEY
# North Korea GPE
# Opera ORG
# today DATE
# Crypto Browser Project ORG
# Windows ORG
# Android ORG
# Cathie Wood PERSON
# 2018 DATE
# Tesla ORG
# $672 billion MONEY
# Tesla ORG
# +4563 ORG
# Today DATE
# today DATE
# 18.7% PERCENT
# 24 hours TIME
# 1 CARDINAL

# %% [markdown]
# ---
